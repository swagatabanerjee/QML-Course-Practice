# %% [markdown]
# <a href="https://colab.research.google.com/github/swagatabanerjee/QML-Course-Practice/blob/main/Assignment4_Question5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 5 — Two independent Hadamards**
#
# Predict the histogram shape for two independently Hadamard qubits before building the circuit, then confirm your prediction.

# %%
# %pip install qiskit
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_histogram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 77.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Initial State:$$\vert{}\psi_0\rangle = \vert{}00\rangle = \vert{}0\rangle \otimes \vert{}0\rangle$$Apply Hadamard ($H$) to $q_0$:$$H\vert{}0\rangle = \vert{}+\rangle = \frac{1}{\sqrt{2}}(\vert{}0\rangle + \vert{}1\rangle)$$Apply Hadamard ($H$) to $q_1$:
#
#     H|0⟩=|+⟩=12–√(|0⟩+|1⟩)
#
# Applying $H$ independently to both $q_0$ and $q_1$ puts the system into an equal superposition of all 2-qubit computational basis states:$$\vert{}\psi_{\text{final}}\rangle = (H\vert{}0\rangle) \otimes (H\vert{}0\rangle) = \frac{1}{2}(\vert{}00\rangle + \vert{}01\rangle + \vert{}10\rangle + \vert{}11\rangle)$$The probability of measuring any specific outcome $x \in \{00, 01, 10, 11\}$ is given by $\vert{}P(x)\vert{}^2$:$$P(00) = \left\vert{}\frac{1}{2}\right\vert{}^2 = 0.25 \quad (25\%)$$$$P(01) = \left\vert{}\frac{1}{2}\right\vert{}^2 = 0.25 \quad (25\%)$$$$P(10) = \left\vert{}\frac{1}{2}\right\vert{}^2 = 0.25 \quad (25\%)$$$$P(11) = \left\vert{}\frac{1}{2}\right\vert{}^2 = 0.25 \quad (25\%)$$Predicted Histogram ShapeThe resulting histogram will be completely flat (uniform distribution) across all four outcomes: 00, 01, 10, and 11, with each state showing an equal probability of $0.25$ ($25\%$) (or approximately equal counts on a real simulator with shot noise).

# %%
# Initialize a 2-qubit circuit
qc = QuantumCircuit(2)

# Apply H gates to both qubits independently
qc.h(0)
qc.h(1)

# Verify the probabilities/statevector
state = Statevector.from_instruction(qc)
probabilities = state.probabilities_dict()

print("Probabilities:", probabilities)
# Outputs: {'00': 0.25, '01': 0.25, '10': 0.25, '11': 0.25}

plot_histogram(probabilities)
# Out:
# Probabilities: {np.str_('00'): np.float64(0.2499999999999999), np.str_('01'): np.float64(0.2499999999999999), np.str_('10'): np.float64(0.2499999999999999), np.str_('11'): np.float64(0.2499999999999999)}
